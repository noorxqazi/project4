# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import make_scorer, recall_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report

# %%
# Study data files

Food_Insecurity_path = "Ressources/Food_Insecurity.csv"
No_Health_Insurance_path = "Ressources/No_Health_Insurance.csv"
Severe_Housing_Cost_Burden_Percent_path = "Ressources/Severe_Housing_Cost_Burden_Percent.csv"

# Read the  data and the study results
Food_Insecurity = pd.read_csv(Food_Insecurity_path)
No_Health_Insurance = pd.read_csv(No_Health_Insurance_path)
No_Health_Insurance = pd.read_csv(No_Health_Insurance_path)
Severe_Housing_Cost_Burden_Percent = pd.read_csv(Severe_Housing_Cost_Burden_Percent_path)
# Severe_Housing_Cost_Burden_Percent = pd.read_csv(Severe_Housing_Cost_Burden_Percent_path)
# display(Food_Insecurity)
# Severe_Housing_Cost_Burden_Percent_path.head()
# No_Health_Insurance


#  print(Severe_Housing_Cost_Burden_Percent)

# %%
Severe_Housing_Cost_Burden_Percent
# Out:
#                                                   Year  County_FIPS  \
# 0                                                 2018      13143.0
# 1                                                 2018      13219.0
# 2                                                 2018      13113.0
# 3                                                 2018      13023.0
# 4                                                 2018      13125.0
# ..                                                 ...          ...
# 155                                               2018      13245.0
# 156                                               2018      13021.0
# 157                                               2018      13217.0
# 158                                               2018      13185.0
# 159  US Diabetes Surveillance System; www.cdc.gov/d...          NaN
#
#               County    State  Diagnosed Diabetes Percentage  \
# 0    Haralson County  Georgia                            5.9
# ...

# %%
Severe_Housing_Cost_Burden_Percent.drop(index = 159)
# Out:
#      Year  County_FIPS           County    State  \
# 0    2018      13143.0  Haralson County  Georgia
# 1    2018      13219.0    Oconee County  Georgia
# 2    2018      13113.0   Fayette County  Georgia
# 3    2018      13023.0  Bleckley County  Georgia
# 4    2018      13125.0  Glascock County  Georgia
# ..    ...          ...              ...      ...
# 154  2018      13261.0    Sumter County  Georgia
# 155  2018      13245.0  Richmond County  Georgia
# 156  2018      13021.0      Bibb County  Georgia
# 157  2018      13217.0    Newton County  Georgia
# 158  2018      13185.0   Lowndes County  Georgia
#
#      Diagnosed Diabetes Percentage  Severe Housing Cost Burden
# 0                              5.9                   12.094718
# 1                              6.7                    7.374326
# 2                              6.8                   10.598770
# 3                              6.9                   11.980627
# ...

# %%
No_Health_Insurance.drop(index = 159)

# %%
# No_Health_Insurance
# Out:
#      Year  County_FIPS           County    State  \
# 0    2018      13143.0  Haralson County  Georgia
# 1    2018      13219.0    Oconee County  Georgia
# 2    2018      13113.0   Fayette County  Georgia
# 3    2018      13023.0  Bleckley County  Georgia
# 4    2018      13125.0  Glascock County  Georgia
# ..    ...          ...              ...      ...
# 154  2018      13261.0    Sumter County  Georgia
# 155  2018      13245.0  Richmond County  Georgia
# 156  2018      13021.0      Bibb County  Georgia
# 157  2018      13217.0    Newton County  Georgia
# 158  2018      13185.0   Lowndes County  Georgia
#
#      Diagnosed Diabetes Percentage  No Health Insurance
# 0                              5.9                 12.3
# 1                              6.7                  6.7
# 2                              6.8                  7.2
# 3                              6.9                  9.5
# 4                              7.0                  7.2
# ...

# %%
# No_Health_Insurance = No_Health_Insurance.drop(index = 159)

# %%
Food_Insecurity = Food_Insecurity.drop(index = 159)
Food_Insecurity
# Out:
#      Year  County_FIPS           County    State  \
# 0    2018      13143.0  Haralson County  Georgia
# 1    2018      13219.0    Oconee County  Georgia
# 2    2018      13113.0   Fayette County  Georgia
# 3    2018      13023.0  Bleckley County  Georgia
# 4    2018      13125.0  Glascock County  Georgia
# ..    ...          ...              ...      ...
# 154  2018      13261.0    Sumter County  Georgia
# 155  2018      13245.0  Richmond County  Georgia
# 156  2018      13021.0      Bibb County  Georgia
# 157  2018      13217.0    Newton County  Georgia
# 158  2018      13185.0   Lowndes County  Georgia
#
#      Diagnosed Diabetes Percentage  Food Insecurity
# 0                              5.9             15.0
# 1                              6.7              8.0
# 2                              6.8              7.1
# 3                              6.9             14.2
# 4                              7.0             14.5
# ..                             ...              ...
# ...

# %%
No_Health_Insurance[['Year', 'County_FIPS', 'County', 'State', 'Diagnosed Diabetes Percentage']] == Food_Insecurity[['Year', 'County_FIPS', 'County', 'State', 'Diagnosed Diabetes Percentage']]
# Out:
#      Year  County_FIPS  County  State  Diagnosed Diabetes Percentage
# 0    True         True    True   True                           True
# 1    True         True    True   True                           True
# 2    True         True    True   True                           True
# 3    True         True    True   True                           True
# 4    True         True    True   True                           True
# ..    ...          ...     ...    ...                            ...
# 155  True         True    True   True                           True
# 156  True         True    True   True                           True
# 157  True         True    True   True                           True
# 158  True         True    True   True                           True
# 159  True        False   False  False                          False
#
# [160 rows x 5 columns]

# %%
Healthcare_df = Food_Insecurity.copy()

# %%
Healthcare_df['No Health Insurance'] = No_Health_Insurance['No Health Insurance']

# %%
Healthcare_df
# Out:
#      Year  County_FIPS           County    State  \
# 0    2018      13143.0  Haralson County  Georgia
# 1    2018      13219.0    Oconee County  Georgia
# 2    2018      13113.0   Fayette County  Georgia
# 3    2018      13023.0  Bleckley County  Georgia
# 4    2018      13125.0  Glascock County  Georgia
# ..    ...          ...              ...      ...
# 154  2018      13261.0    Sumter County  Georgia
# 155  2018      13245.0  Richmond County  Georgia
# 156  2018      13021.0      Bibb County  Georgia
# 157  2018      13217.0    Newton County  Georgia
# 158  2018      13185.0   Lowndes County  Georgia
#
#      Diagnosed Diabetes Percentage  Food Insecurity  No Health Insurance
# 0                              5.9             15.0                 12.3
# 1                              6.7              8.0                  6.7
# 2                              6.8              7.1                  7.2
# 3                              6.9             14.2                  9.5
# ...

# %%
# Healthcare_df1 = Healthcare_df.copy()

# %%
# Healthcare_df1['No Health Insurance'] = Severe Housing Cost Burden['Severe Housing Cost Burden']

# Healthcare_df1
# Out:
#   File "/var/folders/dx/v43z685j1cq_3ms8rmp__0780000gn/T/ipykernel_84959/3739468597.py", line 1
#     Healthcare_df1['No Health Insurance'] = Severe Housing Cost Burden['Severe Housing Cost Burden']
#                                                    ^
# SyntaxError: invalid syntax

# %%
Healthcare_df[['Year', 'County_FIPS', 'County', 'State', 'Diagnosed Diabetes Percentage']] == Severe_Housing_Cost_Burden_Percent[['Year', 'County_FIPS', 'County', 'State', 'Diagnosed Diabetes Percentage']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/dx/v43z685j1cq_3ms8rmp__0780000gn/T/ipykernel_84959/9470096.py in <module>
# ----> 1 Healthcare_df[['Year', 'County_FIPS', 'County', 'State', 'Diagnosed Diabetes Percentage']] == Severe_Housing_Cost_Burden_Percent[['Year', 'County_FIPS', 'County', 'State', 'Diagnosed Diabetes Percentage']]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
# ...

# %%
# merge these two table

# merge_dataframe_df = pd.merge(Food_Insecurity, No_Health_Insurance, encoding='utf8', index=False")
